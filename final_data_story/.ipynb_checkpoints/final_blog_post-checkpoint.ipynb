# %% [markdown]
# # Vaccines, COVID & The Cure for Mistrust: Linguistic Analysis of Anti-vax on Social Media
# *By: Paul Caroline*
#
# <img src="res/bird_mask.jpg" alt="Logo" width="600">

# %% [markdown]
# ## Introduction 👋
# The ongoing COVID-19 pandemic has, in many ways, come as a day of reckoning for the people of the United States. Poltical polarization, social upheaval, and widespread uncertainty has affected many in unprecedented ways. Perhaps many months of quarantine and lockdowns haas driven millions of Americans deeper into their own circles of digital media influence. The first 100 million doses of the COVID-19 vaccine have already been administered, and there are nonetheless, a variety of sentiments concerning its, efficacy and safety, as well as the motives of its creators. As the conversation unfolds against the backdrop of this historical time, it is clear that there is much to learn about the people of the U.S., and about the dynamics of trust amid a crisis.
#
# ## Capturing the Conversation 💬
# There is a tremendous amount of potential in modern micro-blogging. Short-form content created by millions of users enables the analysis of large corpora of human language in real time. This study, therefore, aims to gauge the state of the conversation surrounding the anti-vaccination movement by analyzing data that has been scraped from Twitter.
#
# Two distinct sets of tweets have been selected, one spanning rougly a year since the start of the pandemic, and the other spanning a time frame extending from 2015 to 2016. The latter time period coincides with the passing and full enactment of California Senate Bill 277, which excluded an American parent's personal belief as a justification to exempt children immunizations.
#
# It is expected that analysis of these tweets will indicate a greater sense of gravity, as well as more nuanced modes of skepticism concerning the coronavirus vaccine as opposed to previous immunizations. Amid the perception of a global threat, it is also likely that more people will lean on the counsel of celebrities and organizational leaders when they are unsure of whom to trust. The subsequent analyses will seek to elucidate the veracity of such hypotheses.
#
# Tweets were scraped using the `snscrape` library, and the following hashtags were used to query the results for each respective time frame:
# <table width="700" align="left" style="text-align:left; width:100%;">
#        <tr>
#           <td>
#              <ul>
#                 <li>#sb277</li>
#                 <li>#cdcwhistleblower</li>
#                 <li>#vaccineswork</li>
#                 <li>#antivaccine</li>
#                 <li>#antivax</li>
#                 <li>#vaxxed</li>
#                 <li>#vaccinedamage</li>
#                 <li>#Educateb4uVax</li>
#                 <li>#StopMandatoryVaccination</li>
#                 <li>#VaççinesKill</li>
#              </ul>
#           </td>
#           <td>
#              <ul>
#                 <li>#vaccines</li>
#                 <li>#bigpharmakills</li>
#                 <li>#tannersdad</li>
#                 <li>#vaccineinjured</li>
#                 <li>#vaccinecult</li>
#                 <li>#markofthebeast</li>
#                 <li>#vaccineinjuryisreal</li>
#                 <li>#vaccinefailure</li>
#                 <li>#BigPharmaSins</li>
#                 <li>va$$ines</li>
#              </ul>
#           </td>
#        </tr>
#     </table>

# %%
# Retrieve Necessary Functions & Data
# %run res/boilerplate.ipynb

# %% [markdown]
# ### Counting Words 🧮
# <img src="res/count.gif" alt="Logo" width="400">
#
# The following code cells list the top twenty most prevalent pre-COVID and post-COVID tokens/words as reported by an object containing their frequency distributions.

# %%
pre_dist.most_common(20)
# Out:
# [('.', 2724),
#  ('to', 2005),
#  ('the', 1597),
#  (':', 1565),
#  (',', 1327),
#  ('#CDCwhistleblower', 1110),
#  ('#vaccines', 1000),
#  ('of', 949),
#  ('in', 880),
#  ('#antivax', 854),
#  ('and', 805),
#  ('#SB277', 769),
#  ('a', 745),
#  ('?', 713),
#  ('!', 700),
#  ('#antivaccine', 683),
#  ('is', 630),
#  ('&', 614),
#  ('#VaccinesWork', 604),
#  ('for', 589)]

# %%
post_dist.most_common(20)
# Out:
# [('.', 5360),
#  ('the', 3587),
#  (',', 3293),
#  ('to', 2677),
#  ('!', 1787),
#  ('of', 1747),
#  ('and', 1587),
#  ('a', 1577),
#  ('in', 1254),
#  ('’', 1183),
#  ('is', 1134),
#  ('#COVID19', 1112),
#  ('?', 1002),
#  ('#VaccinesWork', 971),
#  ('#antivax', 958),
#  ('#vaccines', 946),
#  ('I', 919),
#  ('for', 909),
#  ('you', 875),
#  ('are', 864)]

# %% [markdown]
# Taking a crude look at token frequencies seems to suggest some basic patterns. Prior to the pandemic, for example, there was a rougly equal frequency of question marks and exclamation marks. However, exclamation marks take greater precedecence in the latter sample. This might reinforce the idea that people intended to speak with conviction in response to a graver situation. It is also worth noting the general increase in these punction marks. Between the two time periods, there was a 41% increase in the usage of question marks, and a 155% percent increase in the usage of exclamation marks. Such a dramatic change might indicate a more confrontational or argumentative posture to the anti-vaccination conversation. This idea is also supported by the second corpus's frequent use of the words 'I' and 'you,' which do not even make it to the top 20 most frequent words list in the first corpus.
#
# A keyness analysis would be more appropriate to further identify patterns within the two bodies of text. The following figure highlights keywords that are characteristic of either of the corpora.
#
# ### Keyness Analysis 🔑
# The following cell highlights the key words that most closely belong to a particular corpus, thus enabling the identification of key differences.

# %%
plot_keywords()

# %% [markdown]
# As to be expected, some temporally-significant hashtags are more closely associated with one a particular corpus. This anaysis also affirms the keyness of exclamation marks in the post-COVID era, thus hinting at the emphatic nature of tweeted messages.
#
# Another important element of this analysis is the presence of changing terminology. Before the pandemic, it was more common to see words like 'vaccines' and 'movement.' However, the latter corpus includes only the singular form of vaccine as a keyword. This likely results from the fact that the discourse about vaccination, in general, has been overshadowed by the specific public health concern that is confronting the world. Neverthless, it is clear that a movement has taken shape, and persists, given the evolution in phrasing from 'antivaccine movement' to 'antivaxxers.'

# %% [markdown]
# ## Comparing Individuals Across Time ⌚
# In order to properly assess the activity of tweeters across the two time periods, one must control for other factors that would affect the way any particular individual writes. Hence, it is necessary to compare tweets belonging to one single individual. In the study, this involved identifying a total of 97 usernames that were present in both corpora, and looking for differences between each group of tweets.
#
# ### Tweet Frequency 📲
# <img src="res/tweet_time.jpg" alt="Logo" width="400">
#
# The first major difference between each individual's set of tweets was posting frequency; this is illustrated by the following histogram:

# %%
tweet_freq_dist()

# %% [markdown]
# Based on the spread of this plot, it appears that by-and-large, it was more common for people to tweet more often prior to the pandemic. This could be explained, once again, by the idea that the pandemic presents a sobering atmosphere of uncertainty during which people are more careful about what they tweet about regarding the anti-vaccination movement.

# %% [markdown]
# ### Sentiment Analysis 🌡️
# The last stage of the analysis invovled using the `nltk.sentiment.vader` library to assign polarity scores to the text of each tweet belonging to accounts that were represented in both corpora. The tweets with multiple data points were identified and plotted across time to determine how the sentiments changed over time. *It is worth noting that a future study should be concerned with determining whether any conclusions result from simply plotting accounts that tweeted most frequently*. In any case, the plots are given below:

# %%
sentiment_plots()

# %% [markdown]
# The above plots illustrate a common theme, namely, that there is a more of a consistent semblance of a pattern in the valence of the post-COVID tweets. This is liley due to the fact that are in response to a specific event. Further investigation is necessary to determine the cause for such patterns, but the sporadic, nonlinear nature of the pre-COVID plots seems consistent with the atmosphere of a movement that is not yet undergoing widespread crisis.

# %% [markdown]
# ## Conclusion
# The COVID-19 pandemic has proven a formidable trial for many communities around the world, and as safety concerns are on the rise, the way one responds to the crisis often depends ultimately upon whom or what he or she trusts. The aforementioned conclusions, as well as ideas represented in supplemental materials seem to suggest that the nation, as it is represented in social media, is in the middle of a struggle for faith in its institutions. It is not so much a clash of ideology or belief that separates members of society who are for or against vaccines, but rather a disparity of trust. This is evidenced by the keyness of pre-COVID words and hashtags including '#CDCWhistleblower,' '#lies,' and '#markofthebeast,' which associate vaccination with deceit and/or ill-intent, perhaps due to a the tenets of a particular ideology or conspiracy theory. Today, however, one is more likely to see words like 'sue' and '#BigPharmaKills.' While these are also relatively unpleasant words, they indicate an aversion to negligence, not simply blatant malice. If true, this conclusion is a reassuring one, because it means that the nation may not be as polarized as it seems. Many people are skeptical about the way the world is changing, and what is to give rise to the 'new normal.' As people around world work to mitigate the issues surrounding the ongoing public health crisis, there lies the restorative power to foster a sense of integrity in the fabric that holds our socieites together.
